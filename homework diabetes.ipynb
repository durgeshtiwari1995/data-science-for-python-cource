# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
homework= pd.read_csv("/content/pima-indians-diabetes.csv")

# %%
print(homework)
# Out:
#      D1   D2  D3  D4   D5    D6     D7  D8  D9
# 0     6  148  72  35    0  33.6  0.627  50   1
# 1     1   85  66  29    0  26.6  0.351  31   0
# 2     8  183  64   0    0  23.3  0.672  32   1
# 3     1   89  66  23   94  28.1  0.167  21   0
# 4     0  137  40  35  168  43.1  2.288  33   1
# ..   ..  ...  ..  ..  ...   ...    ...  ..  ..
# 763  10  101  76  48  180  32.9  0.171  63   0
# 764   2  122  70  27    0  36.8  0.340  27   0
# 765   5  121  72  23  112  26.2  0.245  30   0
# 766   1  126  60   0    0  30.1  0.349  47   1
# 767   1   93  70  31    0  30.4  0.315  23   0
#
# [768 rows x 9 columns]

# %%
homework.head()

# %%
homework.head(50)

# %%
homework.tail()

# %%
homework.axes

# %%
homework.describe()

# %%
homework.mean()
# Out:
# D1      3.845052
# D2    120.894531
# D3     69.105469
# D4     20.536458
# D5     79.799479
# D6     31.992578
# D7      0.471876
# D8     33.240885
# D9      0.348958
# dtype: float64

# %%
homework.median()

# %%
homework.mode()

# %%
homework.plot()

# %%
homework.values

# %%
homework.shape

# %%
homework.dtypes

# %%
homework.columns
# Out:
# Index(['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9'], dtype='object')

# %%
homework.ndim
# Out:
# 2

# %%
homework.size

# %%
homework.rank()

# %%
homework['D1']>10

# %%
homework.groupby(['D1'],sort=False).describe()

# %%
homework[homework['D1']>10]

# %%
homework[['D7','D1','D2']]

# %%
homework.iloc[0]

# %%
homework.iloc[-1]

# %%
homework.iloc[[10,5],[3,4]]
